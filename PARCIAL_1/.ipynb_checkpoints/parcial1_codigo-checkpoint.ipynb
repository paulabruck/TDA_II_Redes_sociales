# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import linalg as LA
import random
import networkx as nx
import pandas as pd

# %%
df= pd.read_csv("World.csv")
df.head()
# Out:
#              Origen          Destino  ConexionAeropuertos
# 0  Papua New Guinea        Australia                   19
# 1  Papua New Guinea      Philippines                    5
# 2  Papua New Guinea        Indonesia                    2
# 3  Papua New Guinea  Solomon Islands                    2
# 4  Papua New Guinea        Hong Kong                    2

# %%
flights_graph = nx.from_pandas_edgelist(df, source= "Origen",target= "Destino")

# %%
print(flights_graph)
# Out:
# Graph with 229 nodes and 2852 edges

# %%
plt.figure(figsize=(20,20))
nx.draw_networkx(flights_graph, with_labels = True, node_color= 'g', edge_color='y')

# %% [markdown]
#  PARCIAL 1 TDA 2

# %%
print('Diámetro:', nx.diameter(flights_graph))
# Out:
# Diámetro: 5

# %%
def grado_promedio(grafo):
    """
    :param grafo:
    :return: grado promedio (k) del grafo
    """
    total = 0
    for v in grafo:
        total += len(list(grafo.neighbors(v)))
    return total / len(grafo)

# %%
print('Grado Promedio:',grado_promedio(flights_graph))
# Out:
# Grado Promedio: 24.90829694323144

# %%
print('Coeficiente de Clustering Promedio:',nx.average_clustering(flights_graph))
# Out:
# Coeficiente de Clustering Promedio: 0.6601565365859736

# %%
 nx.has_bridges(flights_graph)
# Out:
# True

# %%
list(nx.bridges(flights_graph))
# Out:
# [('Fiji', 'Tuvalu'),
#  ('United States', 'American Samoa'),
#  ('United Kingdom', 'Saint Helena'),
#  ('Canada', 'Saint Pierre and Miquelon'),
#  ('Antigua and Barbuda', 'Montserrat'),
#  ('New Zealand', 'Niue'),
#  ('South Africa', 'Lesotho'),
#  ('South Africa', 'Swaziland'),
#  ('Burma', 'Myanmar')]

# %%
nx.betweenness_centrality(flights_graph)
# Out:
# {'Papua New Guinea': 0.0029144579985688726,
#  'Australia': 0.05396712680185675,
#  'Philippines': 0.0042322766175759,
#  'Indonesia': 0.0035924256107133777,
#  'Solomon Islands': 0.00014644120390358282,
#  'Hong Kong': 0.012754248578738416,
#  'Fiji': 0.021141378015370412,
#  'Japan': 0.020035132237902948,
#  'Singapore': 0.013502839615083348,
#  'China': 0.029591274905900435,
#  'Micronesia': 0.00014072442486539404,
#  'Greenland': 0.0,
#  'Denmark': 0.009929451735101803,
#  'Iceland': 0.0030293107699068357,
#  'Finland': 0.001395755810962359,
#  'Norway': 0.001735567839875596,
#  'Netherlands': 0.03277211291345285,
#  'Sweden': 0.0013601377014614009,
#  'United States': 0.15312826033467095,
#  'Belgium': 0.0255336820467668,
#  'France': 0.1066582564383836,
#  'Germany': 0.03793083275314773,
#  'United Kingdom': 0.07949572806991673,
#  'Canada': 0.04502321245880298,
#  'Switzerland': 0.008252153319960718,
#  'Spain': 0.03799772341776959,
#  'Ireland': 0.00301763708763837,
#  'Faroe Islands': 0.0,
#  'Hungary': 0.0013394166360651385,
#  'Poland': 0.0031370147774500592,
#  'Latvia': 0.00034215282894369773,
#  'Austria': 0.004697381442323384,
#  'Lithuania': 0.0001675860037540019,
#  'Czech Republic': 0.001413986007612805,
#  'Jordan': 0.0017447591153549162,
#  'Antigua and Barbuda': 0.015251026558795254,
#  'Aruba': 0.00011586836541049269,
#  'United Arab Emirates': 0.04606573709425318,
#  'Dominican Republic': 0.006486359758306536,
#  'Bermuda': 0.0,
#  'Barbados': 0.0021671335018400096,
#  'Colombia': 0.0017322320149443886,
#  'Cuba': 0.0036166353579010838,
#  'Mexico': 0.005513947258163121,
#  'Italy': 0.011597040987104046,
#  'Martinique': 0.0006039957879101798,
#  'Cayman Islands': 4.186310121853826e-05,
#  'Bahamas': 0.0003627325549037003,
#  'Grenada': 7.442137766328652e-05,
#  'Brazil': 0.012023236401475621,
#  'South Korea': 0.018644776801229196,
#  'Turkey': 0.05290943296892291,
#  'Jamaica': 0.0010699106738690488,
#  'Peru': 0.0006293718473403824,
#  'Costa Rica': 0.0010094613491871132,
#  'Haiti': 0.00017588966557103073,
#  'Turks and Caicos Islands': 4.79711527705963e-05,
#  'Guadeloupe': 0.0012959244209662063,
#  'Chile': 0.00486060143526383,
#  'Israel': 0.0014877220408469336,
#  'Saint Lucia': 0.001046656060849459,
#  'New Zealand': 0.020930265517386176,
#  'Algeria': 0.0011412620760401719,
#  'Morocco': 0.019488586960111944,
#  'El Salvador': 0.0002323222000482958,
#  'Taiwan': 0.003835379709328513,
#  'Guyana': 0.00015059272211796556,
#  'Trinidad and Tobago': 0.0010639336826871362,
#  'Panama': 0.006356189535685267,
#  'Ethiopia': 0.03421749836748116,
#  'Tunisia': 0.002042886102654329,
#  'Egypt': 0.009351686063217119,
#  'Saint Pierre and Miquelon': 0.0,
#  'Pakistan': 0.0009156890151465776,
#  'Qatar': 0.029936904969256453,
#  'Portugal': 0.010757737440584086,
#  'Russia': 0.015088533456477048,
#  'Saudi Arabia': 0.006836244479736129,
#  'Greece': 0.0018940410495382433,
#  'Puerto Rico': 0.006070442364393799,
#  'Netherlands Antilles': 0.006903147345210992,
#  'India': 0.013784016408036195,
#  'Ukraine': 0.0013788540161062367,
#  'Belize': 1.9321431331633046e-05,
#  'Argentina': 0.0033677355795858855,
#  'Saint Kitts and Nevis': 0.0004320485158123372,
#  'Croatia': 0.00022969006893926684,
#  "Cote d'Ivoire": 0.0019652257372315385,
#  'Lebanon': 0.0009731096108665319,
#  'Mali': 0.00040563909476713436,
#  'Senegal': 0.0032365684373463653,
#  'Niger': 0.00016141592863745533,
#  'Burkina Faso': 0.00020894426269209293,
#  'Libya': 8.235809868520927e-05,
#  'Malta': 0.0004653226006982439,
#  'Mauritania': 5.0815099599839905e-05,
#  'Benin': 0.00019864610574150254,
#  'Togo': 0.0010732859456816662,
#  'Nigeria': 0.004828431143546527,
#  'Equatorial Guinea': 0.0005401564310999643,
#  'Gabon': 0.0007583401088676386,
#  'Cameroon': 0.0004176887155777108,
#  'Ghana': 0.003733401544532488,
#  'Kenya': 0.01910698378280396,
#  'Congo (Brazzaville)': 0.00014231390445940993,
#  'Guinea': 0.00037994184276792816,
#  'Sierra Leone': 0.0002087826511008819,
#  'Liberia': 4.631940742862387e-05,
#  'South Africa': 0.03151538021435897,
#  'Namibia': 0.0004859289112100661,
#  'Gambia': 0.00037709669531108946,
#  'Sao Tome and Principe': 4.3798032437030814e-05,
#  'Congo (Kinshasa)': 0.0010350983598310794,
#  'Chad': 0.00020548527859425686,
#  'Sudan': 0.0004337424383052198,
#  'Rwanda': 0.001072830149633844,
#  'Angola': 0.0034255809973389745,
#  'Cape Verde': 0.0022158397530881407,
#  'Uganda': 0.001495714708952678,
#  'Luxembourg': 0.00022209500734409444,
#  'Serbia': 0.0006789174757146197,
#  'Kuwait': 0.0019647356433773275,
#  'Burundi': 9.871744717736984e-06,
#  'Bulgaria': 0.00010144453598205755,
#  'Slovakia': 2.679030815006827e-05,
#  'Cyprus': 0.0002692811987325967,
#  'Montenegro': 6.214495457542792e-06,
#  'Slovenia': 8.29005907909219e-05,
#  'Estonia': 1.497915303072723e-05,
#  'Romania': 0.00020710014706166264,
#  'Thailand': 0.013801933432257663,
#  'Macedonia': 5.1003413688940545e-05,
#  'Georgia': 0.00037073054702424594,
#  'Belarus': 0.0004250985262357786,
#  'Bosnia and Herzegovina': 2.0751858107417427e-05,
#  'Iran': 0.0013605936266532705,
#  'Albania': 6.340779322455427e-06,
#  'Moldova': 2.4091541601639632e-05,
#  'Malaysia': 0.0049286054387159065,
#  'Guernsey': 0.0,
#  'Jersey': 1.5457145065306438e-05,
#  'Vietnam': 0.001920646516914887,
#  'Maldives': 2.5509599751495625e-05,
#  'Mauritius': 0.0011299520879464195,
#  'Seychelles': 0.00014306820064816791,
#  'Tanzania': 0.002152863289003954,
#  'Bahrain': 0.001438051434544598,
#  'Uzbekistan': 0.0013274909854190597,
#  'Azerbaijan': 0.0006021246608611029,
#  'Kazakhstan': 0.001381711321323888,
#  'Venezuela': 0.0021765804564276986,
#  'Iraq': 0.0006076205506198471,
#  'Tajikistan': 6.302989038436312e-05,
#  'Turkmenistan': 4.2618907022560985e-05,
#  'Sri Lanka': 0.0006694308771676789,
#  'Oman': 0.0016773297635239185,
#  'Gibraltar': 0.0,
#  'Isle of Man': 0.0,
#  'Bangladesh': 0.001293260051705606,
#  'Brunei': 2.399170308002875e-05,
#  'Saint Helena': 0.0,
#  'Falkland Islands': 0.0,
#  'Zimbabwe': 0.00024177513185396913,
#  'Ecuador': 8.893010476630077e-05,
#  'Zambia': 0.000581713658715377,
#  'Suriname': 0.00035354561017930756,
#  'Armenia': 0.00032796808850734315,
#  'Botswana': 5.820538137336872e-06,
#  'Malawi': 3.042358711266664e-05,
#  'Madagascar': 0.0003492721974552447,
#  'Mozambique': 0.0002851520716428607,
#  'Lesotho': 0.0,
#  'Swaziland': 0.0,
#  'Reunion': 0.0007248290456793654,
#  'Central African Republic': 2.9287440371301683e-05,
#  'Comoros': 6.316503754753485e-05,
#  'Mayotte': 0.00025242362336687016,
#  'Djibouti': 0.0007570820271885931,
#  'Guinea-Bissau': 6.440477110544348e-06,
#  'Guatemala': 9.494099422087713e-05,
#  'Western Sahara': 0.0,
#  'Bolivia': 4.293651407029565e-06,
#  'Uruguay': 4.293651407029565e-06,
#  'Paraguay': 4.293651407029565e-06,
#  'Honduras': 0.00013650314624936551,
#  'Somalia': 4.293651407029565e-06,
#  'South Sudan': 1.4644418191832982e-05,
#  'Yemen': 0.00024901123988654974,
#  'Eritrea': 3.941408435172489e-05,
#  'Syria': 2.903093849071127e-05,
#  'French Guiana': 9.291405392592176e-05,
#  'Virgin Islands': 0.0023023070415705863,
#  'Afghanistan': 3.471081570171361e-05,
#  'Kyrgyzstan': 6.984991990040164e-05,
#  'Nepal': 0.00040663422825617916,
#  'British Virgin Islands': 3.94243855231039e-05,
#  'Nicaragua': 1.4598414783900523e-05,
#  'Cook Islands': 2.9693108756405762e-05,
#  'French Polynesia': 0.0003470963005020186,
#  'Samoa': 0.0,
#  'Kiribati': 0.0012076696590326065,
#  'Tuvalu': 0.0,
#  'Tonga': 0.0,
#  'Vanuatu': 4.802755788148786e-05,
#  'New Caledonia': 0.0013291609997589215,
#  'Wallis and Futuna': 0.0,
#  'Nauru': 0.00023699165547077847,
#  'Marshall Islands': 0.0022126975073785884,
#  'American Samoa': 0.0,
#  'Niue': 0.0,
#  'Norfolk Island': 0.0,
#  'Cambodia': 0.00019651544350277704,
#  'Burma': 0.008797034538052185,
#  'Macau': 0.0003709990959031936,
#  'Northern Mariana Islands': 0.0,
#  'Guam': 0.004247715182059957,
#  'Palau': 0.0009633947305996593,
#  'Mongolia': 4.608486851251394e-05,
#  'Laos': 0.0,
#  'Anguilla': 0.0,
#  'Dominica': 0.00019258699411725148,
#  'Montserrat': 0.0,
#  'Saint Vincent and the Grenadines': 0.00025298358300308334,
#  'North Korea': 9.592682451755362e-06,
#  'Bhutan': 0.0,
#  'Myanmar': 0.0,
#  'East Timor': 0.0,
#  'Christmas Island': 0.0,
#  'Cocos (Keeling) Islands': 0.0}

# %%
erdos_renyi_graph= nx.erdos_renyi_graph(229,0.11)
plt.figure(figsize=(20,20))
nx.draw_networkx(erdos_renyi_graph, with_labels = True, node_color= 'g', edge_color='y')

# %%
print('Coeficiente de Clustering Promedio Erdos Renyi:',nx.average_clustering(erdos_renyi_graph))
# Out:
# Coeficiente de Clustering Promedio Erdos Renyi: 0.11077508395626687

# %%
def alfa_preferential_attachment(grafo, x_m):
    """
    Calcula por maxima verosimilitud el valor del exponente de la ley de potencias a la que corresponde un grafo.
    :param grafo:
    :param x_m: valor a partir del cual se empieza a cumplir la ley de potencias
    :return: alfa
    """
    sumatoria = 0
    for v in grafo:
        cant_ady = len(list(grafo.neighbors(v)))
        if cant_ady >= x_m:
            sumatoria += ln(cant_ady / x_m)
    return 1 + len(grafo) / sumatoria

# %%
print(alfa_preferential_attachment(flights_graph, 10))
# Out:
# 2.449890843293105

# %%
def elegir_preferntial(grafo, banned):
    grados_entrada = [0] * len(grafo)
    total = 0
    for v in range(len(grafo)):
        for w in grafo.neighbors(v):
            if w in banned:
                continue
            grados_entrada[w] += 1
            total += 1
    if total == 0:
        return None

    aleat = random.uniform(0, total)
    sumando = 0
    for i in range(len(grafo)):
        sumando += grados_entrada[i]
        if sumando > aleat:
            return i


def preferential_attachment(dirigido, alfa, cant, k):
    p = 1 - (1/(alfa - 1))
    valores = list(range(cant))
    g = nx.DiGraph() if dirigido else nx.Graph()
    g.add_nodes_from(valores)
    for v in range(cant):
        banned = set([v])
        for i in range(int(k)):
            preferential = random.uniform(0, 1) < p
            ya_agregado = False
            if preferential and v > 0:
                w = elegir_preferntial(g, banned)
                if w is not None:
                    banned.add(w)
                    g.add_edge(v, w)
                    ya_agregado = False
            if not ya_agregado:
                w = random.choice(list(set(range(cant)) - set([v])))
                g.add_edge(v, w)

    return g

# %%
pref_graph = preferential_attachment(False, 2.45, 229, 10)
print(pref_graph)
# Out:
# Graph with 229 nodes and 2837 edges

# %%
plt.figure(figsize=(20,20))
nx.draw_networkx(pref_graph, with_labels = True, node_color= 'g', edge_color='y')

# %%
from embeddings import anoymous_walks
caminos, embeding_flight = anoymous_walks(flights_graph, 7)
print(embeding_flight)
# Out:
# [1.84230746e-04 2.99374962e-04 4.60576864e-05 1.15144216e-05
#  7.02379718e-04 3.45432648e-05 4.60576864e-05 3.45432648e-05
#  5.75721080e-05 1.03629794e-04 3.91490334e-04 4.60576864e-05
#  1.49687481e-04 5.18148972e-04 6.54019147e-03 1.15144216e-04
#  1.15144216e-05 3.56947070e-04 3.45432648e-05 3.45432648e-05
#  2.41802854e-04 1.72716324e-04 4.60576864e-05 5.75721080e-05
#  2.17622568e-03 0.00000000e+00 1.15144216e-05 1.26658638e-04
#  0.00000000e+00 2.30288432e-05 1.15144216e-04 0.00000000e+00
#  3.45432648e-05 1.15144216e-05 6.79350875e-04 1.15144216e-05
#  1.03629794e-04 3.45432648e-05 7.13894139e-04 1.15144216e-05
#  3.45432648e-05 3.45432648e-05 5.06634551e-04 2.18774010e-04
#  1.15144216e-05 1.61201902e-04 2.16471126e-03 3.45432648e-04
#  3.33918226e-04 7.94495091e-04 2.31439874e-03 4.39850905e-02
#  6.90865296e-05 1.15144216e-05 9.21153728e-05 0.00000000e+00
#  2.30288432e-05 8.06009512e-05 2.30288432e-05 4.60576864e-05
#  2.30288432e-05 8.63581620e-04 2.30288432e-05 2.30288432e-05
#  2.30288432e-05 0.00000000e+00 1.15144216e-05 9.21153728e-05
#  1.15144216e-05 2.30288432e-05 8.06009512e-05 9.44182571e-04
#  3.45432648e-05 5.75721080e-05 5.75721080e-05 6.44807610e-04
#  0.00000000e+00 5.75721080e-05 2.30288432e-05 2.64831697e-04
#  0.00000000e+00 2.30288432e-05 1.15144216e-05 2.87860540e-04
#  1.84230746e-04 1.38173059e-04 1.15144216e-04 5.98749923e-04
