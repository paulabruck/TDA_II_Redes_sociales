# %% [markdown]
# # PARCIAL 3

# %% [markdown]
# ### PUNTO 4

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# - Construccion Grafo G1 (aleatorio de Erdös-Rényi)

# %%
n=10
m=9
seed = 20160 
G1 = nx.gnm_random_graph(n, m, seed=seed)

# %%
pos = nx.spring_layout(G1, seed=seed)  # Seed for reproducible layout
plt.figure(figsize=(20,15))
plt.title('Grafo 1 -----> Erdos Renyi')
nx.draw(G1, pos=pos)
plt.show()

# %% [markdown]
# - Construccion Grafo G2 (ley de potencias en la distribución de los grados)

# %%
G2 = nx.barabasi_albert_graph(n,m, seed=seed)

# %%
pos = nx.spring_layout(G2, seed=seed)  # Seed for reproducible layout
plt.figure(figsize=(20,15))
plt.title('Grafo 2 -----> Prefferential Attachment')
nx.draw(G2, pos=pos)
plt.show()

# %% [markdown]
# ### SIMULACION 1

# %%
import EoN
gamma = 0.2  
beta = 1.2 
r_0 = beta/gamma
print(r_0)
N = 100 # population size
I0 = 1   # intial n° of infected individuals 
R0 = 0
S0 = N - I0 -R0
pos = nx.spring_layout(G1)
nx_kwargs = {"with_labels":True, "pos": pos, "width": 10, "alpha": 0.7} #optional arguments to be passed on to the
#networkx plotting command.
print("doing Gillespie simulation")
sim = EoN.Gillespie_SIR(G1, tau = beta, gamma=gamma, rho = I0/N, transmission_weight="weight", return_full_data=True)
print("done with simulation, now plotting")
for i in range(0,5,1):
    sim.display(time = i,  **nx_kwargs)
    plt.axis('off') 
    plt.title("Iteration {}".format(i))
    plt.draw()
# Out:
# 5.999999999999999
# doing Gillespie simulation
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /var/folders/s6/xxqd69bd1xn9h0158rllkm8m0000gn/T/ipykernel_46133/1467034596.py in <module>
#      12 #networkx plotting command.
#      13 print("doing Gillespie simulation")
# ---> 14 sim = EoN.Gillespie_SIR(G1, tau = beta, gamma=gamma, rho = I0/N, transmission_weight="weight", return_full_data=True)
#      15 print("done with simulation, now plotting")
#      16 for i in range(0,5,1):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/EoN/simulation.py in Gillespie_SIR(G, tau, gamma, initial_infecteds, initial_recovereds, rho, tmin, tmax, recovery_weight, transmission_weight, return_full_data, sim_kwargs)
#    3145
#    3146     total_rate = total_recovery_rate + total_transmission_rate
# -> 3147     delay = random.expovariate(total_rate)
#    3148     t += delay
#    3149
#
# ~/opt/anaconda3/lib/python3.9/random.py in expovariate(self, lambd)
#     617         # we use 1-random() instead of random() to preclude the
#     618         # possibility of taking the log of zero.
# --> 619         return -_log(1.0 - self.random()) / lambd
#     620
#     621     def vonmisesvariate(self, mu, kappa):
#
# ZeroDivisionError: float division by zero

# %%
import networkx as nx
g=nx.watts_strogatz_graph(n=100, k=4, p=0.6)
plt.figure(figsize=(40,40))
nx.draw_circular(g, with_labels = True)

# %%
import random
E = g.number_of_edges()
#initializing random weights
w = [random.random() for i in range(E)]
s = max(w)
w = [ i/s for i in w ] #normalizing
len(w)
k = 0
for i, j in g.edges():
    g[i][j]['weight'] = w[k]
    k+=1
import matplotlib.pyplot as plt
edgewidth = [d['weight'] for (u,v,d) in g.edges(data=True)]
# layout
#pos = nx.spring_layout(G, iterations=50)
pos = nx.spring_layout(g)
labels = {}
for i in range(100):
    labels[i] = i
# rendering
plt.figure(figsize=(40,40))
nx.draw_networkx_nodes(g, pos)
nx.draw_networkx_edges(g, pos, width=edgewidth, node_size=500)
nx.draw_networkx_labels(g, pos, labels)
plt.axis('off')
# Out:
# (-0.9443599740578759,
#  1.0925885701932323,
#  -0.688201342882743,
#  0.6533358660630976)

# %%
import EoN
gamma = 0.2  
beta = 1.2 
r_0 = beta/gamma
print(r_0)
N = 100 # population size
I0 = 1   # intial n° of infected individuals 
R0 = 0
S0 = N - I0 -R0
pos = nx.spring_layout(g)
nx_kwargs = { "pos": pos, "alpha": 0.7} #optional arguments to be passed on to the
#networkx plotting command.
print("doing Gillespie simulation")
sim = EoN.Gillespie_SIR(g, tau = beta, gamma=gamma, rho = I0/N, transmission_weight="weight", return_full_data=True)
print("done with simulation, now plotting")
for i in range(0,5,1):
    sim.display(time = i,  **nx_kwargs)
    plt.axis('off') 
    plt.title("Iteration {}".format(i))
    plt.draw()
# Out:
# 5.999999999999999
# doing Gillespie simulation
# done with simulation, now plotting

# %%
sim.display(time = 7,  **nx_kwargs)
# Out:
# (<AxesSubplot:>,
#  [<AxesSubplot:title={'center':'$S$'}>,
#   <AxesSubplot:title={'center':'$I$'}>,
#   <AxesSubplot:title={'center':'$R$'}, xlabel='$t$'>])
